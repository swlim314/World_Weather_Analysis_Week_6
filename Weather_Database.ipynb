# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from scipy import stats

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=eb1b2826bbb3c4b7713cb45e7cc2762b

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 599

# %%
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
        city_country = city_weather["sys"]["country"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_description,
                          "Country": city_country,
                          "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | calabazar de sagua
# Processing Record 2 of Set 1 | antofagasta
# Processing Record 3 of Set 1 | yertarskiy
# Processing Record 4 of Set 1 | arraial do cabo
# Processing Record 5 of Set 1 | galyugayevskaya
# Processing Record 6 of Set 1 | busselton
# Processing Record 7 of Set 1 | karratha
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | avarua
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | chacabuco
# Processing Record 13 of Set 1 | bouza
# Processing Record 14 of Set 1 | bolshoy tsaryn
# City not found. Skipping...
# Processing Record 15 of Set 1 | cabedelo
# Processing Record 16 of Set 1 | zheleznodorozhnyy
# Processing Record 17 of Set 1 | punta arenas
# Processing Record 18 of Set 1 | kununurra
# Processing Record 19 of Set 1 | rikitea
# Processing Record 20 of Set 1 | tabou
# Processing Record 21 of Set 1 | bredasdorp
# Processing Record 22 of Set 1 | hambantota
# Processing Record 23 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 1 | beloha
# Processing Record 25 of Set 1 | dillon
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | hilo
# Processing Record 28 of Set 1 | bengkulu
# Processing Record 29 of Set 1 | vila velha
# Processing Record 30 of Set 1 | ostrovnoy
# Processing Record 31 of Set 1 | albany
# Processing Record 32 of Set 1 | kampong chhnang
# Processing Record 33 of Set 1 | vostok
# Processing Record 34 of Set 1 | winchester
# Processing Record 35 of Set 1 | chokurdakh
# Processing Record 36 of Set 1 | meulaboh
# Processing Record 37 of Set 1 | tuktoyaktuk
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | takoradi
# Processing Record 41 of Set 1 | bluff
# Processing Record 42 of Set 1 | yellowknife
# Processing Record 43 of Set 1 | dayong
# Processing Record 44 of Set 1 | ancud
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | san policarpo
# Processing Record 47 of Set 1 | ondorhaan
# City not found. Skipping...
# Processing Record 48 of Set 1 | bambous virieux
# Processing Record 49 of Set 1 | canakkale
# Processing Record 50 of Set 1 | bandarbeyla
# Processing Record 1 of Set 2 | nelson bay
# Processing Record 2 of Set 2 | camacha
# Processing Record 3 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 4 of Set 2 | ahipara
# Processing Record 5 of Set 2 | havoysund
# Processing Record 6 of Set 2 | conde
# Processing Record 7 of Set 2 | poyarkovo
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | kibondo
# Processing Record 10 of Set 2 | butaritari
# Processing Record 11 of Set 2 | haines junction
# Processing Record 12 of Set 2 | palmer
# Processing Record 13 of Set 2 | thompson
# Processing Record 14 of Set 2 | bacuit
# City not found. Skipping...
# Processing Record 15 of Set 2 | nikolskoye
# Processing Record 16 of Set 2 | hobart
# Processing Record 17 of Set 2 | alekseyevsk
# Processing Record 18 of Set 2 | saldanha
# Processing Record 19 of Set 2 | shakawe
# Processing Record 20 of Set 2 | atuona
# Processing Record 21 of Set 2 | cap malheureux
# Processing Record 22 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 23 of Set 2 | ribeira grande
# Processing Record 24 of Set 2 | mackay
# Processing Record 25 of Set 2 | pevek
# Processing Record 26 of Set 2 | tasiilaq
# Processing Record 27 of Set 2 | hami
# Processing Record 28 of Set 2 | bambanglipuro
# Processing Record 29 of Set 2 | bull savanna
# Processing Record 30 of Set 2 | bocana de paiwas
# Processing Record 31 of Set 2 | lorengau
# Processing Record 32 of Set 2 | gawler
# Processing Record 33 of Set 2 | flinders
# Processing Record 34 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 35 of Set 2 | kodiak
# Processing Record 36 of Set 2 | san pedro
# Processing Record 37 of Set 2 | bokoro
# Processing Record 38 of Set 2 | mount isa
# Processing Record 39 of Set 2 | port hardy
# Processing Record 40 of Set 2 | cuite
# Processing Record 41 of Set 2 | chuy
# Processing Record 42 of Set 2 | barrow
# Processing Record 43 of Set 2 | vaini
# Processing Record 44 of Set 2 | geraldton
# Processing Record 45 of Set 2 | wadi maliz
# Processing Record 46 of Set 2 | turukhansk
# Processing Record 47 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 48 of Set 2 | zarand
# Processing Record 49 of Set 2 | cape town
# Processing Record 50 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 3 | russell
# Processing Record 2 of Set 3 | kiboga
# Processing Record 3 of Set 3 | linhares
# Processing Record 4 of Set 3 | faanui
# Processing Record 5 of Set 3 | upernavik
# Processing Record 6 of Set 3 | norman wells
# Processing Record 7 of Set 3 | east london
# Processing Record 8 of Set 3 | port alfred
# Processing Record 9 of Set 3 | longyearbyen
# Processing Record 10 of Set 3 | namatanai
# Processing Record 11 of Set 3 | ulladulla
# Processing Record 12 of Set 3 | lagos
# Processing Record 13 of Set 3 | lazaro cardenas
# Processing Record 14 of Set 3 | zyryanka
# Processing Record 15 of Set 3 | grand gaube
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | mahebourg
# Processing Record 18 of Set 3 | paamiut
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | ponta do sol
# Processing Record 21 of Set 3 | chumikan
# Processing Record 22 of Set 3 | okha
# Processing Record 23 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 3 | kapaa
# Processing Record 25 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 26 of Set 3 | luderitz
# Processing Record 27 of Set 3 | klaksvik
# Processing Record 28 of Set 3 | owando
# Processing Record 29 of Set 3 | eina
# Processing Record 30 of Set 3 | puerto ayora
# Processing Record 31 of Set 3 | san patricio
# Processing Record 32 of Set 3 | kavaratti
# Processing Record 33 of Set 3 | mzimba
# Processing Record 34 of Set 3 | sao filipe
# Processing Record 35 of Set 3 | harper
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 38 of Set 3 | bismarck
# Processing Record 39 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 40 of Set 3 | seoul
# Processing Record 41 of Set 3 | nouadhibou
# Processing Record 42 of Set 3 | talaya
# Processing Record 43 of Set 3 | marzuq
# Processing Record 44 of Set 3 | henties bay
# Processing Record 45 of Set 3 | atar
# Processing Record 46 of Set 3 | port lincoln
# Processing Record 47 of Set 3 | tshikapa
# Processing Record 48 of Set 3 | iqaluit
# Processing Record 49 of Set 3 | markova
# Processing Record 50 of Set 3 | caravelas
# Processing Record 1 of Set 4 | vardo
# Processing Record 2 of Set 4 | ilulissat
# Processing Record 3 of Set 4 | muzhi
# Processing Record 4 of Set 4 | faya
# Processing Record 5 of Set 4 | naze
# Processing Record 6 of Set 4 | bucerias
# Processing Record 7 of Set 4 | bay-khaak
# Processing Record 8 of Set 4 | kerrville
# Processing Record 9 of Set 4 | cabo san lucas
# Processing Record 10 of Set 4 | castro
# Processing Record 11 of Set 4 | lata
# Processing Record 12 of Set 4 | bilma
# Processing Record 13 of Set 4 | pierre
# Processing Record 14 of Set 4 | xuddur
# Processing Record 15 of Set 4 | axim
# Processing Record 16 of Set 4 | airai
# Processing Record 17 of Set 4 | buenos aires
# Processing Record 18 of Set 4 | karlshamn
# Processing Record 19 of Set 4 | kaitangata
# Processing Record 20 of Set 4 | dikson
# Processing Record 21 of Set 4 | saint-philippe
# Processing Record 22 of Set 4 | peniche
# Processing Record 23 of Set 4 | beringovskiy
# Processing Record 24 of Set 4 | grenaa
# Processing Record 25 of Set 4 | narsaq
# Processing Record 26 of Set 4 | puerto quijarro
# Processing Record 27 of Set 4 | lagoa
# Processing Record 28 of Set 4 | fort nelson
# Processing Record 29 of Set 4 | sao felix do xingu
# Processing Record 30 of Set 4 | san cristobal
# Processing Record 31 of Set 4 | margate
# Processing Record 32 of Set 4 | los llanos de aridane
# Processing Record 33 of Set 4 | porto novo
# Processing Record 34 of Set 4 | alofi
# Processing Record 35 of Set 4 | shchors
# Processing Record 36 of Set 4 | nara
# Processing Record 37 of Set 4 | komsomolskiy
# Processing Record 38 of Set 4 | itarema
# Processing Record 39 of Set 4 | touros
# Processing Record 40 of Set 4 | kavieng
# Processing Record 41 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 4 | san antonio
# Processing Record 45 of Set 4 | isangel
# Processing Record 46 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 4 | huarmey
# Processing Record 48 of Set 4 | lima
# Processing Record 49 of Set 4 | rawson
# Processing Record 50 of Set 4 | shediac
# Processing Record 1 of Set 5 | lebedinyy
# Processing Record 2 of Set 5 | tunduru
# City not found. Skipping...
# Processing Record 3 of Set 5 | yar-sale
# Processing Record 4 of Set 5 | bemidji
# Processing Record 5 of Set 5 | celestun
# Processing Record 6 of Set 5 | eydhafushi
# Processing Record 7 of Set 5 | richards bay
# Processing Record 8 of Set 5 | rio cuarto
# Processing Record 9 of Set 5 | pacific grove
# Processing Record 10 of Set 5 | berlevag
# Processing Record 11 of Set 5 | hasaki
# Processing Record 12 of Set 5 | portland
# Processing Record 13 of Set 5 | souillac
# Processing Record 14 of Set 5 | mantua
# Processing Record 15 of Set 5 | alta floresta
# Processing Record 16 of Set 5 | matara
# Processing Record 17 of Set 5 | bloemfontein
# Processing Record 18 of Set 5 | guerrero negro
# Processing Record 19 of Set 5 | pisco
# Processing Record 20 of Set 5 | padang
# Processing Record 21 of Set 5 | rio gallegos
# Processing Record 22 of Set 5 | ust-kulom
# Processing Record 23 of Set 5 | hay river
# Processing Record 24 of Set 5 | kembe
# Processing Record 25 of Set 5 | aksu
# Processing Record 26 of Set 5 | guebwiller
# Processing Record 27 of Set 5 | zaykovo
# Processing Record 28 of Set 5 | saskylakh
# Processing Record 29 of Set 5 | kitgum
# Processing Record 30 of Set 5 | waunakee
# Processing Record 31 of Set 5 | porto walter
# Processing Record 32 of Set 5 | barrancabermeja
# Processing Record 33 of Set 5 | dingle
# Processing Record 34 of Set 5 | dera bugti
# Processing Record 35 of Set 5 | manokwari
# Processing Record 36 of Set 5 | lebu
# Processing Record 37 of Set 5 | tabukiniberu
# City not found. Skipping...
# Processing Record 38 of Set 5 | nizhneyansk
# City not found. Skipping...
# Processing Record 39 of Set 5 | kingisepp
# Processing Record 40 of Set 5 | santa ana
# Processing Record 41 of Set 5 | anloga
# Processing Record 42 of Set 5 | sterling
# Processing Record 43 of Set 5 | nago
# Processing Record 44 of Set 5 | morondava
# Processing Record 45 of Set 5 | vanimo
# Processing Record 46 of Set 5 | elat
# Processing Record 47 of Set 5 | louisbourg
# City not found. Skipping...
# Processing Record 48 of Set 5 | pozzallo
# Processing Record 49 of Set 5 | soyo
# Processing Record 50 of Set 5 | vestmannaeyjar
# Processing Record 1 of Set 6 | charters towers
# Processing Record 2 of Set 6 | samarai
# Processing Record 3 of Set 6 | mayor pablo lagerenza
# Processing Record 4 of Set 6 | saint-pierre
# Processing Record 5 of Set 6 | leshukonskoye
# Processing Record 6 of Set 6 | tanete
# Processing Record 7 of Set 6 | buala
# Processing Record 8 of Set 6 | basoko
# Processing Record 9 of Set 6 | paracuru
# Processing Record 10 of Set 6 | veraval
# Processing Record 11 of Set 6 | praya
# Processing Record 12 of Set 6 | provideniya
# Processing Record 13 of Set 6 | kawalu
# Processing Record 14 of Set 6 | podbrdo
# Processing Record 15 of Set 6 | trairi
# Processing Record 16 of Set 6 | la palma
# Processing Record 17 of Set 6 | prince rupert
# Processing Record 18 of Set 6 | esperance
# Processing Record 19 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 20 of Set 6 | alugan
# Processing Record 21 of Set 6 | hualmay
# Processing Record 22 of Set 6 | abu samrah
# Processing Record 23 of Set 6 | erzin
# Processing Record 24 of Set 6 | kindia
# Processing Record 25 of Set 6 | imeni poliny osipenko
# Processing Record 26 of Set 6 | brindisi
# Processing Record 27 of Set 6 | octeville
# Processing Record 28 of Set 6 | galiwinku
# City not found. Skipping...
# Processing Record 29 of Set 6 | la libertad
# Processing Record 30 of Set 6 | wiwili
# Processing Record 31 of Set 6 | emba
# Processing Record 32 of Set 6 | naryan-mar
# Processing Record 33 of Set 6 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 6 | lieksa
# Processing Record 35 of Set 6 | gangotri
# City not found. Skipping...
# Processing Record 36 of Set 6 | marawi
# Processing Record 37 of Set 6 | vaitupu
# City not found. Skipping...
# Processing Record 38 of Set 6 | namibe
# Processing Record 39 of Set 6 | candido mendes
# Processing Record 40 of Set 6 | sorvag
# City not found. Skipping...
# Processing Record 41 of Set 6 | zhanatas
# City not found. Skipping...
# Processing Record 42 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 43 of Set 6 | khatanga
# Processing Record 44 of Set 6 | prado
# Processing Record 45 of Set 6 | necochea
# Processing Record 46 of Set 6 | mahuva
# Processing Record 47 of Set 6 | milton
# Processing Record 48 of Set 6 | severo-yeniseyskiy
# Processing Record 49 of Set 6 | ola
# Processing Record 50 of Set 6 | shadrinsk
# Processing Record 1 of Set 7 | srednekolymsk
# Processing Record 2 of Set 7 | formoso do araguaia
# City not found. Skipping...
# Processing Record 3 of Set 7 | riyadh
# Processing Record 4 of Set 7 | poum
# Processing Record 5 of Set 7 | nizwa
# Processing Record 6 of Set 7 | qui nhon
# Processing Record 7 of Set 7 | adrar
# Processing Record 8 of Set 7 | bonthe
# Processing Record 9 of Set 7 | cawayan
# Processing Record 10 of Set 7 | tiznit
# Processing Record 11 of Set 7 | cidreira
# Processing Record 12 of Set 7 | saint george
# Processing Record 13 of Set 7 | lavrentiya
# Processing Record 14 of Set 7 | comodoro rivadavia
# Processing Record 15 of Set 7 | praia da vitoria
# Processing Record 16 of Set 7 | bonavista
# Processing Record 17 of Set 7 | barao de melgaco
# Processing Record 18 of Set 7 | yandyrka
# City not found. Skipping...
# Processing Record 19 of Set 7 | pangnirtung
# Processing Record 20 of Set 7 | severo-kurilsk
# Processing Record 21 of Set 7 | aykhal
# Processing Record 22 of Set 7 | gigmoto
# Processing Record 23 of Set 7 | sibolga
# Processing Record 24 of Set 7 | weligama
# Processing Record 25 of Set 7 | cherskiy
# Processing Record 26 of Set 7 | belaya gora
# Processing Record 27 of Set 7 | clyde river
# Processing Record 28 of Set 7 | ust-tsilma
# Processing Record 29 of Set 7 | victoria
# Processing Record 30 of Set 7 | liverpool
# Processing Record 31 of Set 7 | kungurtug
# Processing Record 32 of Set 7 | qaqortoq
# Processing Record 33 of Set 7 | sur
# Processing Record 34 of Set 7 | dunedin
# Processing Record 35 of Set 7 | xichang
# Processing Record 36 of Set 7 | pitrufquen
# Processing Record 37 of Set 7 | belmonte
# Processing Record 38 of Set 7 | mosetse
# Processing Record 39 of Set 7 | arlit
# Processing Record 40 of Set 7 | belyy yar
# Processing Record 41 of Set 7 | tungkang
# City not found. Skipping...
# Processing Record 42 of Set 7 | dangara
# Processing Record 43 of Set 7 | fairbanks
# Processing Record 44 of Set 7 | hammerfest
# Processing Record 45 of Set 7 | strezhevoy
# Processing Record 46 of Set 7 | toftir
# City not found. Skipping...
# Processing Record 47 of Set 7 | kisangani
# Processing Record 48 of Set 7 | socorro
# Processing Record 49 of Set 7 | yulara
# Processing Record 50 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 8 | brewster
# Processing Record 2 of Set 8 | tessalit
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | tuatapere
# Processing Record 5 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 6 of Set 8 | new norfolk
# Processing Record 7 of Set 8 | one hundred mile house
# City not found. Skipping...
# Processing Record 8 of Set 8 | caninde
# Processing Record 9 of Set 8 | avera
# Processing Record 10 of Set 8 | sakaiminato
# Processing Record 11 of Set 8 | tura
# Processing Record 12 of Set 8 | kabanjahe
# Processing Record 13 of Set 8 | pervomayskiy
# Processing Record 14 of Set 8 | elmont
# Processing Record 15 of Set 8 | constitucion
# Processing Record 16 of Set 8 | xining
# Processing Record 17 of Set 8 | rancho palos verdes
# Processing Record 18 of Set 8 | williamsport
# Processing Record 19 of Set 8 | nanortalik
# Processing Record 20 of Set 8 | porbandar
# Processing Record 21 of Set 8 | kathmandu
# Processing Record 22 of Set 8 | afua
# Processing Record 23 of Set 8 | chuguyevka
# Processing Record 24 of Set 8 | roald
# Processing Record 25 of Set 8 | te anau
# Processing Record 26 of Set 8 | benguela
# Processing Record 27 of Set 8 | pinotepa nacional
# Processing Record 28 of Set 8 | vypolzovo
# Processing Record 29 of Set 8 | tagusao
# Processing Record 30 of Set 8 | sabha
# Processing Record 31 of Set 8 | sumbe
# Processing Record 32 of Set 8 | rodrigues alves
# Processing Record 33 of Set 8 | sovetskaya
# Processing Record 34 of Set 8 | puerto escondido
# Processing Record 35 of Set 8 | yerbogachen
# Processing Record 36 of Set 8 | srandakan
# Processing Record 37 of Set 8 | qingquan
# Processing Record 38 of Set 8 | seydi
# Processing Record 39 of Set 8 | gushikawa
# Processing Record 40 of Set 8 | sitka
# Processing Record 41 of Set 8 | ous
# Processing Record 42 of Set 8 | tingrela
# City not found. Skipping...
# Processing Record 43 of Set 8 | buraydah
# Processing Record 44 of Set 8 | anchorage
# Processing Record 45 of Set 8 | ballina
# Processing Record 46 of Set 8 | sliven
# Processing Record 47 of Set 8 | kemptville
# Processing Record 48 of Set 8 | horta
# Processing Record 49 of Set 8 | nalut
# Processing Record 50 of Set 8 | codrington
# Processing Record 1 of Set 9 | sokoni
# Processing Record 2 of Set 9 | rorvik
# Processing Record 3 of Set 9 | sola
# Processing Record 4 of Set 9 | krasnoborsk
# Processing Record 5 of Set 9 | manakara
# Processing Record 6 of Set 9 | leningradskiy
# Processing Record 7 of Set 9 | taber
# Processing Record 8 of Set 9 | taoudenni
# Processing Record 9 of Set 9 | hervey bay
# Processing Record 10 of Set 9 | windhoek
# Processing Record 11 of Set 9 | bozoum
# Processing Record 12 of Set 9 | auki
# Processing Record 13 of Set 9 | caceres
# Processing Record 14 of Set 9 | phuket
# Processing Record 15 of Set 9 | weilheim
# Processing Record 16 of Set 9 | aripuana
# Processing Record 17 of Set 9 | sabang
# Processing Record 18 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 19 of Set 9 | calama
# Processing Record 20 of Set 9 | pailitas
# Processing Record 21 of Set 9 | cam pha
# City not found. Skipping...
# Processing Record 22 of Set 9 | boueni
# Processing Record 23 of Set 9 | andra
# Processing Record 24 of Set 9 | bethel
# Processing Record 25 of Set 9 | surt
# Processing Record 26 of Set 9 | trincomalee
# Processing Record 27 of Set 9 | znamenskoye
# Processing Record 28 of Set 9 | hefei
# Processing Record 29 of Set 9 | baruun-urt
# Processing Record 30 of Set 9 | savalou
# Processing Record 31 of Set 9 | ziarat
# Processing Record 32 of Set 9 | bathsheba
# Processing Record 33 of Set 9 | mar del plata
# Processing Record 34 of Set 9 | mehamn
# Processing Record 35 of Set 9 | wanning
# Processing Record 36 of Set 9 | tuy hoa
# Processing Record 37 of Set 9 | karwar
# Processing Record 38 of Set 9 | vila do maio
# Processing Record 39 of Set 9 | wamba
# Processing Record 40 of Set 9 | antalaha
# Processing Record 41 of Set 9 | norrtalje
# Processing Record 42 of Set 9 | gravelbourg
# Processing Record 43 of Set 9 | katsuura
# Processing Record 44 of Set 9 | dwarka
# Processing Record 45 of Set 9 | muros
# Processing Record 46 of Set 9 | yushu
# Processing Record 47 of Set 9 | vao
# Processing Record 48 of Set 9 | banning
# Processing Record 49 of Set 9 | sao joao da barra
# Processing Record 50 of Set 9 | walvis bay
# Processing Record 1 of Set 10 | nazret
# Processing Record 2 of Set 10 | erdenet
# Processing Record 3 of Set 10 | tiarei
# Processing Record 4 of Set 10 | satitoa
# City not found. Skipping...
# Processing Record 5 of Set 10 | clemencia
# Processing Record 6 of Set 10 | ust-kuyga
# Processing Record 7 of Set 10 | killin
# Processing Record 8 of Set 10 | ningxiang
# Processing Record 9 of Set 10 | fortuna
# Processing Record 10 of Set 10 | sovkhoznyy
# Processing Record 11 of Set 10 | johi
# Processing Record 12 of Set 10 | dubai
# Processing Record 13 of Set 10 | feltre
# Processing Record 14 of Set 10 | bantry
# Processing Record 15 of Set 10 | ust-kan
# Processing Record 16 of Set 10 | tinskoy
# Processing Record 17 of Set 10 | atakpame
# Processing Record 18 of Set 10 | wildeshausen
# Processing Record 19 of Set 10 | aracati
# Processing Record 20 of Set 10 | bursol
# City not found. Skipping...
# Processing Record 21 of Set 10 | andenes
# Processing Record 22 of Set 10 | corinth
# Processing Record 23 of Set 10 | akdepe
# Processing Record 24 of Set 10 | bolshaya chernigovka
# City not found. Skipping...
# Processing Record 25 of Set 10 | san quintin
# Processing Record 26 of Set 10 | haimen
# Processing Record 27 of Set 10 | umm ruwabah
# City not found. Skipping...
# Processing Record 28 of Set 10 | hovd
# Processing Record 29 of Set 10 | vozrozhdeniye
# Processing Record 30 of Set 10 | chengmai
# City not found. Skipping...
# Processing Record 31 of Set 10 | mollendo
# Processing Record 32 of Set 10 | warrington
# Processing Record 33 of Set 10 | akureyri
# Processing Record 34 of Set 10 | caarapo
# Processing Record 35 of Set 10 | aksarka
# Processing Record 36 of Set 10 | qeshm
# Processing Record 37 of Set 10 | port-gentil
# Processing Record 38 of Set 10 | mwense
# Processing Record 39 of Set 10 | inhambane
# Processing Record 40 of Set 10 | bara
# Processing Record 41 of Set 10 | sorland
# Processing Record 42 of Set 10 | darhan
# Processing Record 43 of Set 10 | pangody
# Processing Record 44 of Set 10 | tsabong
# Processing Record 45 of Set 10 | aliwal north
# Processing Record 46 of Set 10 | omboue
# Processing Record 47 of Set 10 | ojinaga
# Processing Record 48 of Set 10 | tala
# Processing Record 49 of Set 10 | tongchuan
# Processing Record 50 of Set 10 | kauhajoki
# Processing Record 1 of Set 11 | vilhena
# Processing Record 2 of Set 11 | abadan
# Processing Record 3 of Set 11 | san vicente
# Processing Record 4 of Set 11 | nome
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | belawan
# Processing Record 7 of Set 11 | krasnokamensk
# Processing Record 8 of Set 11 | rantepao
# Processing Record 9 of Set 11 | erenhot
# Processing Record 10 of Set 11 | amderma
# City not found. Skipping...
# Processing Record 11 of Set 11 | santiago del estero
# Processing Record 12 of Set 11 | berzunti
# Processing Record 13 of Set 11 | baiyin
# Processing Record 14 of Set 11 | carnot
# Processing Record 15 of Set 11 | palaikastron
# Processing Record 16 of Set 11 | vicuna
# Processing Record 17 of Set 11 | bogale
# Processing Record 18 of Set 11 | unidad
# Processing Record 19 of Set 11 | kilakarai
# Processing Record 20 of Set 11 | namtsy
# Processing Record 21 of Set 11 | cooma
# Processing Record 22 of Set 11 | otane
# Processing Record 23 of Set 11 | mersing
# Processing Record 24 of Set 11 | puteyets
# Processing Record 25 of Set 11 | imbituba
# Processing Record 26 of Set 11 | najran
# Processing Record 27 of Set 11 | kuito
# Processing Record 28 of Set 11 | urfa
# City not found. Skipping...
# Processing Record 29 of Set 11 | kushima
# Processing Record 30 of Set 11 | hirara
# Processing Record 31 of Set 11 | cayenne
# Processing Record 32 of Set 11 | southampton
# Processing Record 33 of Set 11 | orlik
# Processing Record 34 of Set 11 | woodstock
# Processing Record 35 of Set 11 | leh
# Processing Record 36 of Set 11 | kulachi
# Processing Record 37 of Set 11 | gediz
# Processing Record 38 of Set 11 | coquimbo
# Processing Record 39 of Set 11 | yatou
# Processing Record 40 of Set 11 | sleaford
# Processing Record 41 of Set 11 | touba
# Processing Record 42 of Set 11 | usinsk
# Processing Record 43 of Set 11 | talnakh
# Processing Record 44 of Set 11 | stornoway
# Processing Record 45 of Set 11 | aberdeen
# Processing Record 46 of Set 11 | port macquarie
# Processing Record 47 of Set 11 | chokwe
# Processing Record 48 of Set 11 | jumla
# Processing Record 49 of Set 11 | ponta delgada
# Processing Record 50 of Set 11 | tapaua
# City not found. Skipping...
# Processing Record 1 of Set 12 | cananeia
# Processing Record 2 of Set 12 | mahibadhoo
# Processing Record 3 of Set 12 | madimba
# Processing Record 4 of Set 12 | nouakchott
# Processing Record 5 of Set 12 | ouallam
# Processing Record 6 of Set 12 | salalah
# Processing Record 7 of Set 12 | vila franca do campo
# Processing Record 8 of Set 12 | coacoyul
# Processing Record 9 of Set 12 | novoselitskoye
# Processing Record 10 of Set 12 | azanka
# Processing Record 11 of Set 12 | krasnaya polyana
# Processing Record 12 of Set 12 | mumford
# Processing Record 13 of Set 12 | hohhot
# Processing Record 14 of Set 12 | gat
# Processing Record 15 of Set 12 | bokhan
# Processing Record 16 of Set 12 | rozivka
# Processing Record 17 of Set 12 | oistins
# Processing Record 18 of Set 12 | manadhoo
# Processing Record 19 of Set 12 | kodinsk
# Processing Record 20 of Set 12 | maceio
# Processing Record 21 of Set 12 | saint anthony
# Processing Record 22 of Set 12 | gbarnga
# Processing Record 23 of Set 12 | cochrane
# Processing Record 24 of Set 12 | cristalina
# Processing Record 25 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 26 of Set 12 | san juan
# Processing Record 27 of Set 12 | natal
# Processing Record 28 of Set 12 | zhitikara
# City not found. Skipping...
# Processing Record 29 of Set 12 | setermoen
# Processing Record 30 of Set 12 | galesong
# Processing Record 31 of Set 12 | pemba
# Processing Record 32 of Set 12 | crotone
# Processing Record 33 of Set 12 | murgab
# Processing Record 34 of Set 12 | quatre cocos
# Processing Record 35 of Set 12 | abha
# Processing Record 36 of Set 12 | kita
# Processing Record 37 of Set 12 | mtwara
# Processing Record 38 of Set 12 | murfreesboro
# Processing Record 39 of Set 12 | matameye
# City not found. Skipping...
# Processing Record 40 of Set 12 | krasne
# Processing Record 41 of Set 12 | ormara
# Processing Record 42 of Set 12 | husavik
# Processing Record 43 of Set 12 | talagang
# Processing Record 44 of Set 12 | yenagoa
# Processing Record 45 of Set 12 | general roca
# Processing Record 46 of Set 12 | naron
# Processing Record 47 of Set 12 | qafsah
# City not found. Skipping...
# Processing Record 48 of Set 12 | jardim
# Processing Record 49 of Set 12 | mana
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Calabazar De Sagua  22.6447  -79.8961     82.87        83          40
# 1         Antofagasta -23.6500  -70.4000     57.90        82         100
# 2          Yertarskiy  56.7902   64.2995     34.23        95          82
# 3     Arraial Do Cabo -22.9661  -42.0278     71.37        88          15
# 4     Galyugayevskaya  43.6969   44.9344     58.14        62          47
# 5           Busselton -33.6500  115.3333     51.51        64           0
# 6            Karratha -20.7377  116.8463     76.06        25         100
# 7             Mataura -46.1927  168.8643     49.62        87          99
# 8              Avarua -21.2078 -159.7750     78.85        69          75
# 9           Jamestown  42.0970  -79.2353     72.72        87          98
#
#    Wind Speed Current Description Country                 Date
# 0        8.05    scattered clouds      CU  2021-09-20 23:03:14
# 1        6.04     overcast clouds      CL  2021-09-20 23:00:09
# 2        5.66       broken clouds      RU  2021-09-20 23:03:14
# 3       27.67          few clouds      BR  2021-09-20 23:03:14
# 4        5.35    scattered clouds      RU  2021-09-20 23:03:14
# 5        9.42           clear sky      AU  2021-09-20 23:03:15
# 6       25.72     overcast clouds      AU  2021-09-20 23:03:15
# 7        3.80     overcast clouds      NZ  2021-09-20 23:03:15
# 8        6.91       broken clouds      CK  2021-09-20 23:03:15
# 9        9.57     overcast clouds      US  2021-09-20 22:59:41

# %%
city_data_final_df = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[city_data_final_df]
city_data_df.head(5)
# Out:
#                  City Country      Lat      Lng  Max Temp  Humidity  \
# 0  Calabazar De Sagua      CU  22.6447 -79.8961     82.87        83
# 1         Antofagasta      CL -23.6500 -70.4000     57.90        82
# 2          Yertarskiy      RU  56.7902  64.2995     34.23        95
# 3     Arraial Do Cabo      BR -22.9661 -42.0278     71.37        88
# 4     Galyugayevskaya      RU  43.6969  44.9344     58.14        62
#
#    Cloudiness  Wind Speed Current Description
# 0          40        8.05    scattered clouds
# 1         100        6.04     overcast clouds
# 2          82        5.66       broken clouds
# 3          15       27.67          few clouds
# 4          47        5.35    scattered clouds

# %%
city_data_df.to_csv('Weather_Data/WeatherPy_database.csv')
